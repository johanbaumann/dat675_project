# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Tuple, Optional, Set, Dict
from collections import defaultdict
import os
import shutil

RANDOM_SEED = 43
np.random.seed(RANDOM_SEED)

from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, Draw
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit import DataStructs
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

# %%
clone_original_folds = [
    ("combination_1950_molecules_and_33_%_synthetic", "combination_1300_molecules_and_0_%_synthetic"),
    ("combination_3900_molecules_and_67_%_synthetic", "combination_1300_molecules_and_0_%_synthetic"),
] # destination directory, source directory

for dst_dir, src_dir in clone_original_folds:
    shutil.copytree(src_dir, dst_dir, dirs_exist_ok=True)

# %%
clone_original_folds = [
    ("combination_1950_molecules_and_33_%_synthetic", "../vae/paper_based/CVAE/fold_pipeline_outputs", 650),
    ("combination_3900_molecules_and_67_%_synthetic", "../vae/paper_based/CVAE/fold_pipeline_outputs", 2600),
] # destination directory, synthetic path, synthetic mol count

for dst_dir, synthetic_path, synthetic_count in clone_original_folds:
    for iteration in range(5):
        iteration_df = pd.read_csv(f"{synthetic_path}/cv_iteration_{iteration}/generated/generated.csv").sample(n=synthetic_count, ignore_index=True)
        iteration_df.to_csv(f"{dst_dir}/synthetic_data_iteration_{iteration}.csv")
